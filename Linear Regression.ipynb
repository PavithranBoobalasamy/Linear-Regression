# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

data = pd.read_csv(r"C:\Users\Pavithran\Desktop\Datasets\Salary_Data.csv")
x_train = data["YearsExperience"]
y_train = data["Salary"]
x_train = np.array(x_train).reshape(-1, 1)
y_train = np.array(y_train)

X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, random_state=1)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# Plot the actual data and the regression line
plt.scatter(X_test, y_test, color='blue', label='Actual Data')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Linear Regression Line')
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.legend()
plt.show()

mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)

w = model.coef_[0]
b = model.intercept_

def predict_salary(years_of_experience):
    salary = (w * years_of_experience) + b
    return salary

years_input = float(input("Enter years of experience: "))

predicted_salary = predict_salary(years_input)
print("Predicted Salary:", predicted_salary)
# Out:
# Mean Absolute Error: 6185.994575326634
# Enter years of experience:  2.5
# Predicted Salary: 48942.25984333662
